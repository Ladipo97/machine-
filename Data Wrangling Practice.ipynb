# %%
import pandas as pd
import numpy as np

# %%
data2 = pd.read_csv('Downloads/academicperformance/datasets/train.csv')

# %%
data3 = pd.read_csv('Downloads/academicperformance/datasets/test.csv')

# %%
data2.dtypes
# Out:
# S/N            int64
# Gender        object
# Age            int64
# Location      object
# famsize       object
# Pstatus       object
# Medu           int64
# Fedu           int64
# traveltime     int64
# studytime      int64
# failures       int64
# schoolsup     object
# famsup        object
# paid          object
# activities    object
# nursery       object
# higher        object
# internet      object
# famrel         int64
# freetime       int64
# health         int64
# absences       int64
# Score          int64
# dtype: object

# %%
data3 = pd.read_csv('Downloads/academicperformance/datasets/test.csv')

# %%
data2.describe(include='all')
# Out:
#                S/N Gender         Age Location famsize Pstatus        Medu  \
# count   325.000000    325  325.000000      325     325     325  325.000000
# unique         NaN      2         NaN        2       2       2         NaN
# top            NaN      F         NaN        U     GT3       T         NaN
# freq           NaN    171         NaN      265     234     285         NaN
# mean    163.000000    NaN   11.320000      NaN     NaN     NaN    2.710769
# std      93.963645    NaN    1.123157      NaN     NaN     NaN    1.086977
# min       1.000000    NaN   10.000000      NaN     NaN     NaN    0.000000
# 25%      82.000000    NaN   10.000000      NaN     NaN     NaN    2.000000
# 50%     163.000000    NaN   11.000000      NaN     NaN     NaN    3.000000
# 75%     244.000000    NaN   12.000000      NaN     NaN     NaN    4.000000
# max     325.000000    NaN   17.000000      NaN     NaN     NaN    4.000000
#
# ...

# %%
data2.isnull().sum()
# Out:
# S/N           0
# Gender        0
# Age           0
# Location      0
# famsize       0
# Pstatus       0
# Medu          0
# Fedu          0
# traveltime    0
# studytime     0
# failures      0
# schoolsup     0
# famsup        0
# paid          0
# activities    0
# nursery       0
# higher        0
# internet      0
# famrel        0
# freetime      0
# health        0
# absences      0
# Score         0
# dtype: int64

# %%
#turning categorical variables to numerical variables

#for internet

from sklearn.preprocessing import LabelEncoder,OneHotEncoder
labelencoder_I= LabelEncoder()
data2['internet'] = labelencoder_I.fit_transform(data2['internet'])

# %%
#turning categorical variables to numerical variables

#for higher

from sklearn.preprocessing import LabelEncoder,OneHotEncoder
labelencoder_H= LabelEncoder()
data2['higher'] = labelencoder_H.fit_transform(data2['higher'])

# %%
#turning categorical variables to numerical variables

#for nursery

from sklearn.preprocessing import LabelEncoder,OneHotEncoder
labelencoder_N= LabelEncoder()
data2['nursery'] = labelencoder_N.fit_transform(data2['nursery'])

# %%
#turning categorical variables to numerical variables

#for activities

from sklearn.preprocessing import LabelEncoder,OneHotEncoder
labelencoder_A= LabelEncoder()
data2['activities'] = labelencoder_A.fit_transform(data2['activities'])

# %%
#turning categorical variables to numerical variables

#for paid

from sklearn.preprocessing import LabelEncoder,OneHotEncoder
labelencoder_P= LabelEncoder()
data2['paid'] = labelencoder_P.fit_transform(data2['paid'])

# %%
#turning categorical variables to numerical variables

#for schoolsup   
   
from sklearn.preprocessing import LabelEncoder,OneHotEncoder
labelencoder_S= LabelEncoder()
data2['schoolsup'] = labelencoder_S.fit_transform(data2['schoolsup'])

# %%
#turning categorical variables to numerical variables

#for famsup   
   
from sklearn.preprocessing import LabelEncoder,OneHotEncoder
labelencoder_F= LabelEncoder()
data2['famsup'] = labelencoder_F.fit_transform(data2['famsup'])

# %%
data2.head()
# Out:
#    S/N Gender  Age Location famsize Pstatus  Medu  Fedu  traveltime  \
# 0    1      F   13        U     GT3       A     4     4           2
# 1    2      F   12        U     GT3       T     1     1           1
# 2    3      F   10        U     LE3       T     1     1           1
# 3    4      F   10        U     GT3       T     4     2           1
# 4    5      F   11        U     GT3       T     3     3           1
#
#    studytime  ...    paid  activities  nursery  higher  internet  famrel  \
# 0          2  ...       0           0        1       1         0       4
# 1          2  ...       0           0        0       1         1       5
# 2          2  ...       0           0        1       1         1       4
# 3          3  ...       0           1        1       1         1       3
# 4          2  ...       0           0        1       1         0       4
#
#    freetime  health  absences  Score
# 0         3       3         4     22
# 1         3       3         2     31
# ...

# %%
dummy_variable_1 = pd.get_dummies(data2['Gender'])
dummy_variable_1.head(10)

dummy_variable_1.rename(columns={'F':'Female', 'M':'Male'}, inplace=True)
dummy_variable_1.head(10)

# merge data frame "data2" and "dummy_variable_1" 
data2 = pd.concat([data2, dummy_variable_1], axis=1)

# drop original column "gender" from "data2"
data2.drop("Gender", axis = 1, inplace=True)

# %%
data2.head()
# Out:
#    S/N  Age Location famsize Pstatus  Medu  Fedu  traveltime  studytime  \
# 0    1   13        U     GT3       A     4     4           2          2
# 1    2   12        U     GT3       T     1     1           1          2
# 2    3   10        U     LE3       T     1     1           1          2
# 3    4   10        U     GT3       T     4     2           1          3
# 4    5   11        U     GT3       T     3     3           1          2
#
#    failures  ...   nursery  higher  internet  famrel  freetime  health  \
# 0         0  ...         1       1         0       4         3       3
# 1         0  ...         0       1         1       5         3       3
# 2         0  ...         1       1         1       4         3       3
# 3         0  ...         1       1         1       3         2       5
# 4         0  ...         1       1         0       4         3       5
#
#    absences  Score  Female  Male
# 0         4     22       1     0
# 1         2     31       1     0
# ...

# %%
dummy_variable_2 = pd.get_dummies(data2['Location'])
dummy_variable_2.head(10)

dummy_variable_2.rename(columns={'R':'Rural', 'U':'Urban'}, inplace=True)
dummy_variable_2.head(10)

# merge data frame "data2" and "dummy_variable_1" 
data2 = pd.concat([data2, dummy_variable_2], axis=1)

# drop original column "Location" from "data2"
data2.drop("Location", axis = 1, inplace=True)

# %%
dummy_variable_3 = pd.get_dummies(data2['famsize'])
dummy_variable_3.head(10)

dummy_variable_3.rename(columns={'GT3':'familysize>3', 'LE3':'familysize<=3'}, inplace=True)
dummy_variable_3.head(10)

# merge data frame "data2" and "dummy_variable_1" 
data2 = pd.concat([data2, dummy_variable_3], axis=1)

# drop original column "famsize" from "data2"
data2.drop("famsize", axis = 1, inplace=True)

# %%
dummy_variable_4 = pd.get_dummies(data2['Pstatus'])
dummy_variable_4.head(10)

dummy_variable_4.rename(columns={'T':'parents_together', 'A':'parents_apart'}, inplace=True)
dummy_variable_4.head(10)

# merge data frame "data2" and "dummy_variable_1" 
data2 = pd.concat([data2, dummy_variable_4], axis=1)

# drop original column "Pstatus" from "data2"
data2.drop("Pstatus", axis = 1, inplace=True)

# %%
data2.head()
# Out:
#    S/N  Age  Medu  Fedu  traveltime  studytime  failures  schoolsup  famsup  \
# 0    1   13     4     4           2          2         0          1       0
# 1    2   12     1     1           1          2         0          0       1
# 2    3   10     1     1           1          2         0          1       0
# 3    4   10     4     2           1          3         0          0       1
# 4    5   11     3     3           1          2         0          0       1
#
#    paid        ...         absences  Score  Female  Male  Rural  Urban  \
# 0     0        ...                4     22       1     0      0      1
# 1     0        ...                2     31       1     0      0      1
# 2     0        ...                6     37       1     0      0      1
# 3     0        ...                0     42       1     0      0      1
# 4     0        ...                0     37       1     0      0      1
#
#    familysize>3  familysize<=3  parents_apart  parents_together
# ...

# %%
data2.dtypes
# Out:
# S/N                 int64
# Age                 int64
# Medu                int64
# Fedu                int64
# traveltime          int64
# studytime           int64
# failures            int64
# schoolsup           int64
# famsup              int64
# paid                int64
# activities          int64
# nursery             int64
# higher              int64
# internet            int64
# famrel              int64
# freetime            int64
# health              int64
# absences            int64
# Score               int64
# Female              uint8
# Male                uint8
# Rural               uint8
# Urban               uint8
# familysize>3        uint8
# familysize<=3       uint8
# parents_apart       uint8
# parents_together    uint8
# dtype: object

# %%
#starting for testset(data3)

# %%
data3.dtypes
# Out:
# S/N            int64
# Age            int64
# Location      object
# famsize       object
# Pstatus       object
# Medu           int64
# Fedu           int64
# traveltime     int64
# studytime      int64
# failures       int64
# schoolsup     object
# famsup        object
# paid          object
# activities    object
# nursery       object
# higher        object
# internet      object
# famrel         int64
# freetime       int64
# health         int64
# absences       int64
# dtype: object

# %%
data3.isnull().sum()
# Out:
# S/N           0
# Age           0
# Location      0
# famsize       0
# Pstatus       0
# Medu          0
# Fedu          0
# traveltime    0
# studytime     0
# failures      0
# schoolsup     0
# famsup        0
# paid          0
# activities    0
# nursery       0
# higher        0
# internet      0
# famrel        0
# freetime      0
# health        0
# absences      0
# dtype: int64

# %%
data3.head()
# Out:
#    S/N  Age Location famsize Pstatus  Medu  Fedu  traveltime  studytime  \
# 0  327   12        U     LE3       A     3     2           1          1
# 1  328   13        R     LE3       T     1     1           2          4
# 2  329   13        U     GT3       T     1     1           2          2
# 3  330   12        U     GT3       T     2     2           1          2
# 4  331   13        U     GT3       T     2     1           2          2
#
#    failures    ...    famsup paid activities nursery higher internet famrel  \
# 0         0    ...        no   no         no     yes    yes      yes      4
# 1         0    ...       yes   no        yes     yes    yes       no      5
# 2         0    ...        no   no        yes     yes    yes      yes      5
# 3         0    ...       yes   no         no      no    yes      yes      5
# 4         0    ...        no   no        yes     yes    yes      yes      4
#
#    freetime  health  absences
# 0         4       3        18
# ...

# %%
dummy_variable_5 = pd.get_dummies(data3['Location'])
dummy_variable_5.head(10)

dummy_variable_5.rename(columns={'R':'Rural', 'U':'Urban'}, inplace=True)
dummy_variable_5.head(10)

# merge data frame "data3" and "dummy_variable_1" 
data3 = pd.concat([data3, dummy_variable_5], axis=1)

# drop original column "Location" from "data3"
data3.drop("Location", axis = 1, inplace=True)

# %%
dummy_variable_6 = pd.get_dummies(data3['famsize'])
dummy_variable_6.head(10)

dummy_variable_6.rename(columns={'GT3':'familysize>3', 'LE3':'familysize<=3'}, inplace=True)
dummy_variable_6.head(10)

# merge data frame "data3" and "dummy_variable_1" 
data3 = pd.concat([data3, dummy_variable_6], axis=1)

# drop original column "famsize" from "data3"
data3.drop("famsize", axis = 1, inplace=True)

# %%
dummy_variable_7 = pd.get_dummies(data3['Pstatus'])
dummy_variable_7.head(10)

dummy_variable_7.rename(columns={'T':'parents_together', 'A':'parents_apart'}, inplace=True)
dummy_variable_7.head(10)

# merge data frame "data3" and "dummy_variable_1" 
data3 = pd.concat([data3, dummy_variable_7], axis=1)

# drop original column "Pstatus" from "data3"
data3.drop("Pstatus", axis = 1, inplace=True)

# %%
#turning categorical variables to numerical variables

#for schoolsup   
   
from sklearn.preprocessing import LabelEncoder,OneHotEncoder
labelencoder_S1= LabelEncoder()
data3['schoolsup'] = labelencoder_S1.fit_transform(data3['schoolsup'])

# %%
#turning categorical variables to numerical variables

#for famsup   
   
from sklearn.preprocessing import LabelEncoder,OneHotEncoder
labelencoder_F1= LabelEncoder()
data3['famsup'] = labelencoder_F1.fit_transform(data3['famsup'])

# %%
#turning categorical variables to numerical variables

#for paid

from sklearn.preprocessing import LabelEncoder,OneHotEncoder
labelencoder_P1= LabelEncoder()
data3['paid'] = labelencoder_P1.fit_transform(data3['paid'])

# %%
#turning categorical variables to numerical variables

#for activities

from sklearn.preprocessing import LabelEncoder,OneHotEncoder
labelencoder_A1= LabelEncoder()
data3['activities'] = labelencoder_A1.fit_transform(data3['activities'])

# %%
#turning categorical variables to numerical variables

#for nursery

from sklearn.preprocessing import LabelEncoder,OneHotEncoder
labelencoder_N1= LabelEncoder()
data3['nursery'] = labelencoder_N1.fit_transform(data3['nursery'])

# %%
#turning categorical variables to numerical variables

#for internet

from sklearn.preprocessing import LabelEncoder,OneHotEncoder
labelencoder_I1= LabelEncoder()
data3['internet'] = labelencoder_I1.fit_transform(data3['internet'])

# %%
#turning categorical variables to numerical variables

#for higher

from sklearn.preprocessing import LabelEncoder,OneHotEncoder
labelencoder_H1= LabelEncoder()
data3['higher'] = labelencoder_H1.fit_transform(data3['higher'])

# %%
data3.dtypes
# Out:
# S/N                 int64
# Age                 int64
# Medu                int64
# Fedu                int64
# traveltime          int64
# studytime           int64
# failures            int64
# schoolsup           int64
# famsup              int64
# paid                int64
# activities          int64
# nursery             int64
# higher              int64
# internet            int64
# famrel              int64
# freetime            int64
# health              int64
# absences            int64
# Rural               uint8
# Urban               uint8
# familysize>3        uint8
# familysize<=3       uint8
# parents_apart       uint8
# parents_together    uint8
# dtype: object

# %%
data3.to_csv('clean_test.csv')

# %%
#data Normalization for train set using simple feature scaling

# %%
#for Age
data2['Age'] = (data2['Age'])/(data2['Age'].max())

# %%
#for absences
data2['absences'] = (data2['absences'])/(data2['absences'].max())

# %%
#for score
data2['Score'] = (data2['Score'])/(data2['Score'].max())

# %%
data2.head()
# Out:
#    S/N       Age  Medu  Fedu  traveltime  studytime  failures  schoolsup  \
# 0    1  0.764706     4     4           2          2         0          1
# 1    2  0.705882     1     1           1          2         0          0
# 2    3  0.588235     1     1           1          2         0          1
# 3    4  0.588235     4     2           1          3         0          0
# 4    5  0.647059     3     3           1          2         0          0
#
#    famsup  paid        ...         absences     Score  Female  Male  Rural  \
# 0       0     0        ...           0.1250  0.415094       1     0      0
# 1       1     0        ...           0.0625  0.584906       1     0      0
# 2       0     0        ...           0.1875  0.698113       1     0      0
# 3       1     0        ...           0.0000  0.792453       1     0      0
# 4       1     0        ...           0.0000  0.698113       1     0      0
#
#    Urban  familysize>3  familysize<=3  parents_apart  parents_together
# ...

# %%
#doing the same for test set(data normalization)

# %%
#for Age
data3['Age'] = (data3['Age'])/(data3['Age'].max())

# %%
#for absences
data3['absences'] = (data3['absences'])/(data3['absences'].max())

# %%
data3.dtypes
# Out:
# S/N                   int64
# Age                 float64
# Medu                  int64
# Fedu                  int64
# traveltime            int64
# studytime             int64
# failures              int64
# schoolsup             int64
# famsup                int64
# paid                  int64
# activities            int64
# nursery               int64
# higher                int64
# internet              int64
# famrel                int64
# freetime              int64
# health                int64
# absences            float64
# Rural                 uint8
# Urban                 uint8
# familysize>3          uint8
# familysize<=3         uint8
# parents_apart         uint8
# parents_together      uint8
# dtype: object

# %%
data2.to_csv("cleantrain.csv")

# %%
data3.to_csv('clean_test.csv')
